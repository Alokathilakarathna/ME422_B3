# %% [markdown]
# #  Rigid Body Controll
#
#
# ---
#
# E/20/395
# --A.P Thilakarathna

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Figure 1-Intermidat cordinate system ans boady cordinate syastem
