# %% [markdown]
# <a href="https://colab.research.google.com/github/Alokathilakarathna/ME422_B3/blob/main/Vibration%20Lab/e20387.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Vibration Lab

# %% [markdown]
# # **Week #1**
#
# ***Activity #1***
#
# **Derive the 2-dof freedom model that will capture the first two dominant modes of small amplitude vibration of the system.**
#
# *Activity #2*
#
# Estimate the damping ratios of the first two dominant modes.
#
# *Activity #3*
#
# Plot the following:
#
# the unforced repsonse to an initiail diplacement of the spring end of the beam
# the forced response for three choices of the rotational speed of the motor
# theoretical frequency response of the system that captures the first two dominant modes of vibration of the system.

# %% [markdown]
# Let's assume the apparatus beam as a pinned-pinned axially loaded beam with axial load P and Length L. A motor of mass M and a accelerometer are mounted on the beam at L/2. The properties of the beam are;
#
#     cross section a =
#     lenght L =
# Two sets of data are collected, at a sampling frequency of 5kz for two operating conditions of the motor that cause large amplitude vibrations of the beam. For the lower frequency motion the maximimum amplitude of vibration is measured to be about x mm.
#
# Assuming that the vibrations of the other nearby devices are transmitted through the base of the axially loaded beam apparatus and that the structure of the axially loaded beam apparatus has a very high degree of flexural rigidity.
#
# Also assuming that the pinned-pinned axially loaded beam with dampingis sufficiently accurately described by the solutions of the partial differential equation given by ------(1)
#
#
# \begin{align}
# {{\partial^2 y} \over {\partial t^2}} + C{{\partial y} \over {\partial t}}+\frac{EI} {\rho A}{{\partial^4 y} \over {\partial x^4}}+\frac{P}{\rho A} {{\partial^2 y} \over {\partial x^2}}&=q(t,x)
# \end{align}
#
# where $y$ is the transverse displacement of the beam with respect to the mid line, $C$ is the damping coefficient of the system, $P$ is the axial compressive force, $\rho$ is the density of the material of the beam, and $E$ is the modulus of rigidity, $I$ is the cross sectional moment of inertia, and $A$ is the cross sectional area of the uniform beam. In this section we will consider the case where the axial load is a constant.

# %% [markdown]
# ***Mathematical solution for the beam:***
#
# It can be shown that, if the displacements are small then the motion of the system is sufficiently accurately described by the solutions of the partial differential equation given by ------(1)
#
# \begin{align}
# {{\partial^2 y} \over {\partial t^2}} + C{{\partial y} \over {\partial t}}+\frac{EI} {\rho A}{{\partial^4 y} \over {\partial x^4}}+\frac{P}{\rho A} {{\partial^2 y} \over {\partial x^2}}&=q(t,x)
# \end{align}
#
# where $y$ is the transverse displacement of the beam with respect to the mid line, $C$ is the damping coefficient of the system, $P$ is the axial compressive force, $\rho$ is the density of the material of the beam, and $E$ is the modulus of rigidity, $I$ is the cross sectional moment of inertia, and $A$ is the cross sectional area of the uniform beam. In this section we will consider the case where the axial load is a constant.
#
# Accounting for the effect of the nearby rotary machines, we will approximate the base excitation of the apparatus, $l(t)$, by
# \begin{align}
# l(t)=\epsilon(\cos{2\pi f_1 t}+\cos{2\pi f_2 t}+\cos{2\pi f_3 t})
# \end{align}
# Then the accelermometer reading is
# \begin{align}
# a(t)&=\dfrac{\partial^2 y}{\partial t^2}+\ddot{l}(t)+\nu_t
# \end{align}
# where $\nu_t\sim \mathfrak{N}(0,\sigma)$ is measurement white noise.
#
# Then
# \begin{align}
# q(t,x)&=f_0\cos{(\omega t)}\delta\left(x-\frac{L}{2}\right)-\ddot{l}-C\dot{l}
# \end{align}
# Compared to $f_0$ we will asume that $\ddot{l}$ and $\dot{l}$ is small and hence that
# \begin{align}
# q(t,x)&\approx f_0\cos{(\omega t)}\delta\left(x-\frac{L}{2}\right)
# \end{align}

# %% [markdown]
# \begin{align}
# \ddot{z}_k+2\zeta_k\omega_k\dot{z}_k+\omega_k^2z_k&=\langle\langle\psi_k(x),q(x,t)\rangle\rangle
# \end{align}
# where $\zeta_k=\frac{C}{2\omega_k}$,  and
# \begin{align}
# \omega_k &= \sqrt{ \frac{k^2 \pi^2}{\rho A L^2} \left( \frac{E I k^2 \pi^2}{L^2} - P \right) }
# \end{align}

# %% [markdown]
# \begin{align}
# y(t, x) = \sum_{k=1}^\infty \chi_{2k-1}(\omega) \cos\left(\omega t + \phi_{2k-1}(\omega)\right) \psi_{2k-1}(x)
# \end{align}
# \begin{align}
# \omega_k &= \sqrt{ \frac{k^2 \pi^2}{\rho A L^2} \left( \frac{E I k^2 \pi^2}{L^2} - P \right)}\\
# \chi_k(\omega) & = \frac{2 f_0}{L} \cdot \left|\frac{\sin(k \pi / 2)}{ \sqrt{(\omega_k^2 - \omega^2)^2+4\zeta_k^2\omega^2\omega_k^2}}\right|\\
# \phi_k(\omega) &=\arctan{\left(\frac{2\zeta_k\omega\omega_k}{\omega_k^2 - \omega^2}\right)}
# \end{align}

# %% [markdown]
# From the damped ocillators we find that:
# $\chi(\omega)$ is maximum when
# \begin{align}
# \omega_{k_r}=\omega_k\sqrt{1-2\zeta_k^2},
# \end{align}
# and that the maximum amplitude of vibration is given by
# \begin{align}
# {y_{ss}}_{k_{max}}=\frac{f_0\sin(k\pi/2)}{L\zeta_k\omega_k^2\sqrt{1-\zeta_k^2}}.
# \end{align}

# %% [markdown]
# Since the measurements are avaialbe only for the first two non-trivial modes of vibration we can approximate the system yesponse of the beam by:
# \begin{align}
# y(t, x) \approx \chi_1(\omega) \cos\left(\omega t + \phi_1(\omega)\right) \sin{\left(\frac{\pi x}{L}\right)}+\chi_3(\omega) \cos\left(\omega t + \phi_3(\omega)\right) \sin{\left(\frac{3\pi x}{L}\right)}
# \end{align}
# \begin{align}
# a(t) \approx -\omega^2\left(\chi_1(\omega) \cos\left(\omega t + \phi_1(\omega)\right)-\chi_3(\omega) \cos\left(\omega t + \phi_3(\omega)\right)\right)+\ddot{l}(t)+\nu_t
# \end{align}

# %% [markdown]
# Hence for the filtered signal
# \begin{align}
# {a_{ss}}_{k_{max}}=\frac{f_0\sin(k\pi/2)}{L\zeta_k\sqrt{1-\zeta_k^2}}.
# \end{align}

# %% [markdown]
# Near resonance. That is when $\omega \approx \omega_k$

# %% [markdown]
# ***First two dominant modes of small amplitude vibration of the system;***

# %%
import numpy as np
import pandas as pd
from numpy import linalg
import scipy as sp
import math
from scipy.integrate import odeint
from IPython.display import HTML
import plotly.graph_objects as go
from sympy import *
from sympy.physics.mechanics import dynamicsymbols, init_vprinting


df=pd.read_csv('ME327_2025_Mid_Assesment_data.csv') #data set

#Performing Fourier Transform on a_1____________________________________________
# where fs is frequenzy (Hz) and a_vals is amplitude (mm)

def plot_fft(fs,a_vals):
    ft_a1 = np.fft.fft(a_vals)
    frequencies_a1 = np.fft.fftfreq(len(a_vals), d=1/fs)

    # Get positive frequencies and corresponding magnitudes
    positive_freqs_a1 = frequencies_a1 > 0
    freqs_plot_a1 = frequencies_a1[positive_freqs_a1]
    magnitude_plot_a1 = np.abs(ft_a1[positive_freqs_a1]) / len(a_vals)

    # Plot using Plotly
    fig = go.Figure()
    fig.add_trace(go.Scatter(
        x=freqs_plot_a1,
        y=magnitude_plot_a1,
        mode='lines',
        name='FFT Magnitude of a'
    ))

    fig.update_layout(
        title="Frequency Spectrum of a",
        xaxis_title="Frequency (Hz)",
        yaxis_title="Magnitude",
        template="plotly_white"
    )

    fig.show()

    a_vals = df['a_1'].values
fs = 5000
plot_fft(fs,a_vals)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2542/3241472245.py in <cell line: 0>()
#      11
#      12
# ---> 13 df=pd.read_csv('ME327_2025_Mid_Assesment_data.csv') #data set
#      14
#      15 #Performing Fourier Transform on a_1____________________________________________
#
# ...

# %%
import numpy as np
from numpy.linalg import det
from scipy.linalg import svd
from scipy.linalg import eigh
from scipy.optimize import brentq
from scipy.integrate import odeint
from scipy.integrate import quad
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
from IPython.display import HTML

#finding the determinent of the Characteristic Matrix
def char_det(beta, l_beam, EI, k_theta):

    bL = beta * l_beam

    H = np.array([
        [2*EI*beta**2,      -k_theta*beta,  -k_theta*beta],
        [np.cosh(bL)+np.cos(bL), np.sinh(bL), -np.sin(bL)],
        [np.sinh(bL)-np.sin(bL), np.cosh(bL), -np.cos(bL)]
    ])

    return det(H)

def find_betas(l_beam, EI, k_theta, n_roots=2, beta_max=50):
    betas = []
    beta_vals = np.linspace(1e-4, beta_max, 5000)

    f_vals = [char_det(b, l_beam, EI, k_theta) for b in beta_vals]

    for i in range(len(beta_vals)-1):
        if f_vals[i]*f_vals[i+1] < 0:
            root = brentq(
                char_det,
                beta_vals[i],
                beta_vals[i+1],
                args=(l_beam, EI, k_theta)
            )
            betas.append(root)

            if len(betas) >= n_roots:
                break

    return np.array(betas)


def mode_shape_coefficients(beta, l_beam, EI, k_theta):
    bL = beta * l_beam

    H = np.array([
        [2*EI*beta**2,      -k_theta*beta,  -k_theta*beta],
        [np.cosh(bL)+np.cos(bL), np.sinh(bL), -np.sin(bL)],
        [np.sinh(bL)-np.sin(bL), np.cosh(bL), -np.cos(bL)]
    ])

    # SVD -> right singular vector corresponding to smallest singular value
    U, S, Vh = svd(H)
    v = Vh[-1, :].copy()   # v ~ [A, B, D] up to sign/scale

    # Solving A,B,C,D Coefficients
    A, B, D = v
    C = -A
    return A, B, C, D

# Beam parameters
b = 0.025          # Breadth
h = 0.01           # Thickness
A = b*h
m_beam = 1.65
l_beam = 0.815     # Beam length
E = 2e+11          # Modulus of Elasticity
I = b * h**3 /12   # Area Moment of Inertia
p = m_beam/(A*l_beam) # Density (kg/m^3

# Spring Parameters
k_spring = 3800   # Spring stiffness
l_spring = 0.75   # Location of spring along beam
m_spring = 0.388  # Spring mass
m_fixed = 0.009   # Fixed mass attached to spring

# Rotational spring at base
k_theta = k_spring * l_spring * l_spring

#Damper Properties
l_damper = 0.2    # Location of damper along beam
m_damper = 0.53   # Mass associated with damper

#Exciter Properties
m_exciter = 4.2   # Exciter mass
l_exciter = 0.4   # Exciter location along beam

# %%
#Finding the first two betas
roots = find_betas(l_beam, E*I, k_theta, n_roots=2)
beta1, beta2 = roots
print(f"beta1 = {beta1:.4f}, beta2 = {beta2:.4f}")

#Mode shape function
def psi(x, beta, l_beam, EI, k_theta):
    A, B, C, D = mode_shape_coefficients(beta, l_beam, EI, k_theta)
    return A*np.cosh(beta*x) + B*np.sinh(beta*x) + C*np.cos(beta*x) + D*np.sin(beta*x)

psi1_spring = psi(l_spring, beta1, l_beam, E*I, k_theta)
psi2_spring = psi(l_spring, beta2, l_beam, E*I, k_theta)

psi1_damper = psi(l_damper, beta1, l_beam, E*I, k_theta)
psi2_damper = psi(l_damper, beta2, l_beam, E*I, k_theta)

psi1_exciter = psi(l_exciter, beta1, l_beam, E*I, k_theta)
psi2_exciter = psi(l_exciter, beta2, l_beam, E*I, k_theta)

print(f"psi1(l_spring) = {psi1_spring:.4f}, psi2(l_spring) = {psi2_spring:.4f}")
print(f"psi1(l_damper) = {psi1_damper:.4f}, psi2(l_damper) = {psi2_damper:.4f}")
print(f"psi1(l_exciter) = {psi1_exciter:.4f}, psi2(l_exciter) = {psi2_exciter:.4f}")
print("\n")
#function for Modal masses
def modal_mass(beta):
    """Integrate rho*A*psi^2 along the beam"""
    integrand = lambda x: p * A * psi(x, beta, l_beam, E*I, k_theta)**2
    m, _ = quad(integrand, 0, l_beam)
    return m

m1 = modal_mass(beta1)
m2 = modal_mass(beta2)

#calculating Natural frequencies
omega1 = (beta1**2) * np.sqrt(E*I/(p*A))
omega2 = (beta2**2) * np.sqrt(E*I/(p*A))

print(f"Calculated modal mass m1 = {m1:.4f} kg, m2 = {m2:.4f} kg")
print("\n")
print(f"Calculated natural frequencies for beam: omega1 = {omega1:.4f} rad/s, omega2 = {omega2:.4f} rad/s")
# Out:
# beta1 = 1.9417, beta2 = 5.1942
# psi1(l_spring) = -1.3706, psi2(l_spring) = -0.8789
# psi1(l_damper) = -0.2491, psi2(l_damper) = 0.7102
# psi1(l_exciter) = -0.6133, psi2(l_exciter) = 0.8923
#
#
# Calculated modal mass m1 = 1.0818 kg, m2 = 0.7688 kg
#
#
# Calculated natural frequencies for beam: omega1 = 54.0892 rad/s, omega2 = 387.0553 rad/s

# %%
M_beam = np.array([[m1, 0.0],
                   [0.0, m2]])
K_beam = np.array([[m1 * omega1**2, 0.0],
                   [0.0, m2 * omega2**2]])

#spring mass
m_eff_spring = (1/3) * m_spring + m_fixed
M_spring = m_eff_spring * np.array([[psi1_spring**2, psi1_spring * psi2_spring],
                                    [psi1_spring * psi2_spring, psi2_spring**2]])

#damper mass
M_damper = m_damper * np.array([[psi1_damper**2, psi1_damper * psi2_damper],
                                [psi1_damper * psi2_damper, psi2_damper**2]])

#exciter mass
M_exciter = m_exciter * np.array([[psi1_exciter**2, psi1_exciter * psi2_exciter],
                                 [psi1_exciter * psi2_exciter, psi2_exciter**2]])

def print_matrix(name, mat):
    print(f"{name}:")
    for row in mat:
        print("  [" + ", ".join(f"{val:10.3f}" for val in row) + "]")
    print()

print_matrix("M_beam", M_beam)
print_matrix("M_spring", M_spring)
print_matrix("M_damper", M_damper)
print_matrix("M_exciter", M_exciter)
print_matrix("K_beam", K_beam)
# Out:
# M_beam:
#   [     1.082,      0.000]
#   [     0.000,      0.769]
#
# M_spring:
#   [     0.260,      0.167]
#   [     0.167,      0.107]
#
# M_damper:
#   [     0.033,     -0.094]
#   [    -0.094,      0.267]
#
# M_exciter:
#   [     1.580,     -2.298]
#   [    -2.298,      3.344]
#
# K_beam:
#   [  3164.958,      0.000]
#   [     0.000, 115171.455]

# %%
#Natural frequencies for full system
M = M_beam + M_spring + M_damper + M_exciter
K = K_beam

eigvals, eigvecs = eigh(K, M)
omega_n = np.sqrt(eigvals)

print("Natural frequencies including the attachments=")
for i, w in enumerate(omega_n, 1):
    print(f"Mode {i}: {w:.3f} rad/s = {w/(2*np.pi):.3f} Hz")

Phi = eigvecs
print_matrix("Modal Matrix", Phi)
# Out:
# Natural frequencies including the attachments=
# Mode 1: 32.472 rad/s = 5.168 Hz
# Mode 2: 204.048 rad/s = 32.475 Hz
# Modal Matrix:
#   [    -0.573,      0.461]
#   [     0.012,      0.596]

# %%
#Modes Shapes of the Beam
x = np.linspace(0, l_beam, 1000)

psi1 = psi(x, beta1, l_beam, E*I, k_theta)
psi2 = psi(x, beta2, l_beam, E*I, k_theta)

psi1_norm = psi1 / np.max(np.abs(psi1))
psi2_norm = psi2 / np.max(np.abs(psi2))

plt.figure(figsize=(7, 3))
plt.plot(x, psi1_norm, label=r'$\psi_1$ (Mode 1)')
plt.plot(x, psi2_norm, label=r'$\psi_2$ (Mode 2)')

plt.xlabel('Position at Beam)')
plt.ylabel('Amplitude')
plt.grid(True)
plt.legend()
plt.show()

# %%
y_o = 0.003
phi11 = Phi[0, 0]
phi12 = Phi[0, 1]
phi21 = Phi[1, 0]
phi22 = Phi[1, 1]

#Mode Shape for Complete System
def psi_star_1(x):
    return phi11 * psi(x, beta1, l_beam, E*I, k_theta) + \
           phi21 * psi(x, beta2, l_beam, E*I, k_theta)

def psi_star_2(x):
    return phi12 * psi(x, beta1, l_beam, E*I, k_theta) + \
           phi22 * psi(x, beta2, l_beam, E*I, k_theta)

psi_star_1_l_beam = psi_star_1(l_beam)
print(f"psi_star_1(l_beam) = {psi_star_1_l_beam:.4f}")

q1_0 = y_o / psi_star_1_l_beam
print(f"Initial modal coordinate q1_0 = {q1_0:.4f}")

#Diagonalised Matrices
M_m = Phi.T @ M @ Phi
K_m = Phi.T @ K @ Phi

zeta1 = 0.008
zeta2 = 0.05
beta = 2 * zeta1 / omega_n[0]

C_m = beta * K_m
# Out:
# psi_star_1(l_beam) = 0.8515
# Initial modal coordinate q1_0 = 0.0035

# %%
def system_ode(q_vec, t, M_m_inv, C_m, K_m):
    q1, q2, q1_dot, q2_dot = q_vec
    q = np.array([q1, q2])
    q_dot = np.array([q1_dot, q2_dot])

    # M_m_inv * (-C_m * q_dot - K_m * q)
    q_ddot = M_m_inv @ (-C_m @ q_dot - K_m @ q)

    return [q1_dot, q2_dot, q_ddot[0], q_ddot[1]]

M_m_inv = np.linalg.inv(M_m)

q1_0_val = q1_0
q2_0_val = 0.0

q_dot1_0 = 0.0
q_dot2_0 = 0.0

q_initial = [q1_0_val, q2_0_val, q_dot1_0, q_dot2_0]

t = np.arange(0, 10, 0.001)

solution = odeint(system_ode, q_initial, t, args=(M_m_inv, C_m, K_m))

q1h_t = solution[:, 0]
q2h_t = solution[:, 1]

# %%
# Damped Natural Response at Free End
z1_t = np.zeros_like(t)
z2_t = np.zeros_like(t)

for i in range(len(t)):
    q_vector = np.array([q1h_t[i], q2h_t[i]])
    z_vector = Phi @ q_vector
    z1_t[i] = z_vector[0]
    z2_t[i] = z_vector[1]

psi1_l_beam = psi(l_beam, beta1, l_beam, E*I, k_theta)
psi2_l_beam = psi(l_beam, beta2, l_beam, E*I, k_theta)

y_l_beam_t = z1_t * psi1_l_beam + z2_t * psi2_l_beam

plt.figure(figsize=(10, 3))
plt.plot(t, y_l_beam_t)
plt.xlabel('Time')
plt.ylabel('Displacement')
plt.title('Unforced Response at the Free End of the Beam')
plt.grid(True)
plt.show()

# %%
y_x_t = np.zeros((len(t), len(x)))

# Animation for the Beam
for i in range(len(t)):
    def psi_star_1_full(x_vals):
        return (phi11 * psi(x_vals, beta1, l_beam, E*I, k_theta) +
                phi21 * psi(x_vals, beta2, l_beam, E*I, k_theta))

    def psi_star_2_full(x_vals):
        return (phi12 * psi(x_vals, beta1, l_beam, E*I, k_theta) +
                phi22 * psi(x_vals, beta2, l_beam, E*I, k_theta))

    y_x_t[i, :] = (
        psi_star_1_full(x) * q1h_t[i] +
        psi_star_2_full(x) * q2h_t[i]
    )

from matplotlib.animation import FuncAnimation
from IPython.display import HTML

fig, ax = plt.subplots(figsize=(7, 3))
ax.set_xlim(0, l_beam)

max_disp = np.max(np.abs(y_x_t)) * 1.1
ax.set_ylim(-max_disp, max_disp)

ax.set_xlabel('Position along Beam')
ax.set_ylabel('Displacement')
ax.set_title('Beam Vibration of unforced response)')
ax.grid(True)

line, = ax.plot([], [], lw=2)

def init():
    line.set_data([], [])
    return line,

def animate(i):
    line.set_data(x, y_x_t[i, :])
    return line,

skip = 10
frames_idx = range(0, len(t), skip)

animation = FuncAnimation(
    fig, animate, init_func=init, frames=frames_idx,
    interval=int((t[1] - t[0]) * skip * 1000),
    blit=True)

plt.close(fig)
HTML(animation.to_html5_video())
# Out:
# <video width="700" height="300" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
#Exciter Parameters ===============
Omega_1 = 32.472
Omega_2 = 100.0
Omega_3 = 204.048

Omega_list = [Omega_1, Omega_2, Omega_3]

m_ecc =  0.0045
r     =  0.035

def compute_Q(m_ecc, r, Omega):
    #return 1.0
    return 2 * m_ecc * r * Omega**2

#ODE solution for Forced Vibration
t = np.arange(0, 7.5, 0.001)

def system_ode_forced(q_vec, t, M_m_inv, C_m, K_m, Omega, Q, psi_star_l):
    q1, q2, q1_dot, q2_dot = q_vec
    q = np.array([q1, q2])
    q_dot = np.array([q1_dot, q2_dot])
    f_physical = psi_star_l * Q * np.sin(Omega * t)
    q_ddot = M_m_inv @ (f_physical - C_m @ q_dot - K_m @ q)

    return [q1_dot, q2_dot, q_ddot[0], q_ddot[1]]

# Initial conditions
q_initial = [0.0, 0.0, 0.0, 0.0]

psi_star_l = np.array([psi_star_1(l_exciter), psi_star_2(l_exciter)])

solutions = []

for Omega in Omega_list:

    Q = compute_Q(m_ecc, r, Omega)

    solution = odeint(system_ode_forced, q_initial, t,
    args=(M_m_inv, C_m, K_m, Omega, Q, psi_star_l)
    )

    solutions.append(solution)

# %%
for idx, Omega in enumerate(Omega_list):

    solution = solutions[idx]
    q1_t = solution[:, 0]
    q2_t = solution[:, 1]

    y_x_t = np.zeros((len(t), len(x)))
    for i in range(len(t)):
        y_x_t[i, :] = (
            psi_star_1_full(x) * q1_t[i] +
            psi_star_2_full(x) * q2_t[i]
        )

    fig, ax = plt.subplots(figsize=(7, 3))
    ax.set_xlim(0, l_beam)

    max_disp = np.max(np.abs(y_x_t)) * 1.1
    ax.set_ylim(-max_disp, max_disp)

    ax.set_xlabel('Position along Beam (m)')
    ax.set_ylabel('Displacement (m)')
    ax.set_title(f'Forced Response, Ω = {Omega:.2f} rad/s')
    ax.grid(True)

    line, = ax.plot([], [], lw=2)

    def init():
        line.set_data([], [])
        return line,

    def animate(i):
        line.set_data(x, y_x_t[i, :])
        return line,

    skip = 10
    frames_idx = range(0, len(t), skip)

    animation = FuncAnimation(
        fig, animate, init_func=init, frames=frames_idx,
        interval=int((t[1] - t[0]) * skip * 1000),
        blit=True
    )

    plt.close(fig)
    display(HTML(animation.to_html5_video()))
# Out:
# <video width="700" height="300" controls autoplay loop>
#   <source type="video/mp4" src="...
# <video width="700" height="300" controls autoplay loop>
#   <source type="video/mp4" src="...
# <video width="700" height="300" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
#Input Beam Positions for FRF
x1 = l_beam
x2 = l_damper
x3 = 0.495

x_vals_f = np.array([x1, x2, x3])

psi1_x = np.array([psi_star_1(x) for x in x_vals_f])
psi2_x = np.array([psi_star_2(x) for x in x_vals_f])

psi1_le = psi_star_1(l_exciter)
psi2_le = psi_star_2(l_exciter)

omega_1, omega_2 = omega_n[0], omega_n[1]

M_m1 = M_m[0, 0]
M_m2 = M_m[1, 1]

def G(x_idx, Omega):

    denom1 = (omega_1**2 - Omega**2) + 1j * (2 * zeta1 * Omega * omega_1)
    denom2 = (omega_2**2 - Omega**2) + 1j * (2 * zeta2 * Omega * omega_2)

    term1 = (psi1_le * psi1_x[x_idx]) / (M_m1 * denom1)
    term2 = (psi2_le * psi2_x[x_idx]) / (M_m2 * denom2)

    return term1 + term2

# %%
#Frequency Response
Omega_vals = np.linspace(0.01, 300, 600)

G_all = np.zeros((3, len(Omega_vals)), dtype=complex)

for i in range(3):
    for j, Omega in enumerate(Omega_vals):
        G_all[i, j] = G(i, Omega)

fig, axs = plt.subplots(1, 2, figsize=(12, 5))

for i in range(3):
    axs[0].plot(Omega_vals, 20 * np.log10(np.abs(G_all[i])), label=f"$x_{i+1}$")
axs[0].set_xlabel(r"$\Omega$")
axs[0].set_ylabel(r"$20\log_{10}|G(x,\Omega)|$ [dB]")
axs[0].set_title("FRF Magnitude (dB)")
axs[0].legend()
axs[0].grid(True)

for i in range(3):
    axs[1].plot(Omega_vals, np.unwrap(np.angle(G_all[i])), label=f"$x_{i+1}$")
axs[1].set_xlabel(r"$\Omega$")
axs[1].set_ylabel(r"$\arg(G(x,\Omega))$ [rad]")
axs[1].set_title("FRF Phase")
axs[1].legend()
axs[1].grid(True)

plt.tight_layout()
plt.show()

# %%
Q1 = compute_Q(m_ecc, r, 32.472)

# Solve the ODE for 1st Mode
solution_single_omega = odeint(system_ode_forced, q_initial, t,
        args=(M_m_inv, C_m, K_m, 32.472, Q1, psi_star_l))

q1_t1 = solution_single_omega[:, 0]
q2_t1 = solution_single_omega[:, 1]

y_x1 = (psi_star_1_full(0.5) * q1_t1 +
             psi_star_2_full(0.5) * q2_t1)

y_max1 = np.max(np.abs(y_x1))

print(f"Maximum displacement at x = 0.5 m within 1st Mode: {y_max1:.7f} m")
# Out:
# Maximum displacement at x = 0.5 m within 1st Mode: 0.0029107 m

# %%
#Absorber Parameters
E_absorber = 2e+11          # Modulus of Elasticity (Pa)
I_absorber = 7.2179e-12     # Area Moment of Inertia (m^4)
m_absorber = 0.438          # Total mass of the absorber setup (kg)
m_mass = 0.121              # Mass of the movable mass (kg)
m_absorberbeam = 0.126      # Beam mass (kg/m)

# Effective modal mass of the absorber
m2_a = m_mass + (33/140) * m_absorberbeam * 0.28

# %%
#calculating Absorber Mass Distance ===============
def calculate_l_absorber(f_hz):
    f_rad_s = 2 * np.pi * f_hz
    numerator = 3 * E_absorber * I_absorber
    denominator = m2_a * (f_rad_s)**2
    l_absorber = (numerator / denominator)**(1/3)
    return l_absorber

f1_experimental = 6.42 #first natural experimental mode
l_absorber_calculated = calculate_l_absorber(f1_experimental)

print(f"Calculated l_absorber: {l_absorber_calculated:.4f} m")
# Out:
# Calculated l_absorber: 0.2740 m

# %%
# Calculating Natural Frequency
c = 16.77
l_absorber = 0.274
k_absorber = (3 * E_absorber * I_absorber)/(l_absorber ** 3)

m_a = M_beam[0, 0] + m_eff_spring * psi1_spring ** 2 + m_damper * psi1_damper ** 2 + m_exciter * psi1_exciter ** 2 + m_absorber * psi1_exciter ** 2
k_a = M_beam[0, 0] * omega1**2

M_elastic = np.array([ [m_a, 0.0],
                  [0.0, m2_a]])

C_elastic = np.array([ [c * (psi_star_1_full(l_damper) ** 2), 0.0],
                  [0.0, 0.0]])

K_elastic = np.array([ [k_a + k_absorber * psi1_exciter**2, -k_absorber * psi1_exciter],
                  [-k_absorber * psi1_exciter, k_absorber]])

eigvals_elastic, eigvecs_elastic = eigh(K_elastic, M_elastic)
omega_n_elastic = np.sqrt(eigvals_elastic)

print("Natural frequencies including absorber:")
for i, w in enumerate(omega_n_elastic, 1):
    print(f"Mode {i}: {w:.3f} rad/s = {w/(2*np.pi):.3f} Hz")
# Out:
# Natural frequencies including absorber:
# Mode 1: 31.251 rad/s = 4.974 Hz
# Mode 2: 41.127 rad/s = 6.546 Hz

# %%
#System Parameters
absorber_beam_length = 0.28

eigvals_elastic, eigvecs_elastic = eigh(K_elastic, M_elastic)
omega_n_elastic = np.sqrt(eigvals_elastic)

# Defining the 3 Frequencies of Interest
frequencies = [
    (omega_n_elastic[0], "Mode 1 (Theoretical)"),
    (2 * np.pi * 6.42,   "Antiresonance (6.42 Hz)"),
    (omega_n_elastic[1], "Mode 2 (Theoretical)")
]

def elastic_eom_simulation(t, state, Omega):
    z, y2, z_dot, y2_dot = state
    q = np.array([z, y2])
    q_dot = np.array([z_dot, y2_dot])
    F_amp = compute_Q(m_ecc, r, Omega)
    F_generalized = F_amp * psi1_exciter * np.sin(Omega * t)

    rhs = np.array([F_generalized, 0.0]) - C_elastic @ q_dot - K_elastic @ q
    acc = np.linalg.solve(M_elastic, rhs)

    return [z_dot, y2_dot, acc[0], acc[1]]

#Animation
x_beam_vals = np.linspace(0, l_beam, 200)
x_abs_vis = np.linspace(0, absorber_beam_length, 40)
psi_shape = psi_star_1_full(x_beam_vals)

for Omega, label in frequencies:
    sol = solve_ivp(elastic_eom_simulation, [0, 15.0], [0,0,0,0],
                    t_eval=np.linspace(10.0, 15.0, 600), args=(Omega,))

    t, z_t, y2_t = sol.t, sol.y[0, :], sol.y[1, :]
    y_x_t = np.outer(z_t, psi_shape) * 1000
    y2_t_mm = y2_t * 1000

    # Setup Plot
    fig, ax = plt.subplots(figsize=(7, 3))
    max_disp = max(np.max(np.abs(y_x_t)), np.max(np.abs(y2_t_mm)), 1.0)
    ax.set(xlim=(0, 0.85), ylim=(-max_disp*1.2, max_disp*1.2),
           xlabel='Position (m)', ylabel='Displacement (mm)', title=f"{label} - {Omega/(2*np.pi):.2f} Hz")
    ax.grid(True)

    beam_line, = ax.plot([], [], lw=2, color='tab:blue')
    abs_line,  = ax.plot([], [], lw=2, color='orange')

    def animate(i):
        beam_line.set_data(x_beam_vals, y_x_t[i, :])
        beam_at_exciter = z_t[i] * psi_star_1_full(l_exciter) * 1000
        abs_line.set_data(l_exciter + x_abs_vis, np.linspace(beam_at_exciter, y2_t_mm[i], len(x_abs_vis)))
        return beam_line, abs_line

    time_interval = (t[1] - t[0]) * 2 * 1000

    anim = FuncAnimation(
    fig, animate,
    frames=range(0, len(t), 2),
    interval=time_interval,
    blit=True)

    plt.close(fig)
    display(HTML(anim.to_html5_video()))
# Out:
# <video width="700" height="300" controls autoplay loop>
#   <source type="video/mp4" src="...
# <video width="700" height="300" controls autoplay loop>
#   <source type="video/mp4" src="...
# <video width="700" height="300" controls autoplay loop>
#   <source type="video/mp4" src="...
